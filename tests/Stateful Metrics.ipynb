# %%
import sys
import os

sys.path.append(os.path.abspath('..'))


from simulation import params_agent_movement_test, state_agent_movement_test, create_sites, create_initial_agents

from math_spec_mapping import load_from_json

"""# For development purposes
sys.path.append(os.path.abspath('../..'))
from MSML.src.math_spec_mapping import (load_from_json)"""

from copy import deepcopy
from src import math_spec_json

ms = load_from_json(deepcopy(math_spec_json))

msi = ms.build_implementation(params_agent_movement_test)

# %%
# Set the randomness to ensure the same outcome each time from random parts
from random import seed
seed(2)

# Set the state and parameters
state, params = msi.prepare_state_and_params(state_agent_movement_test, params_agent_movement_test,
                                             state_preperation_functions=[create_sites, create_initial_agents],
                                             parameter_preperation_functions=[])
assert state["Agents"] == [{'Age': 0, 'Agent Type': 'Prey', 'Food': 5, 'Location': (0, 0)},
 {'Age': 0, 'Agent Type': 'Prey', 'Food': 5, 'Location': (0, 1)},
 {'Age': 0, 'Agent Type': 'Predator', 'Food': 7, 'Location': (1, 1)},
 {'Age': 0, 'Agent Type': 'Prey', 'Food': 5, 'Location': (1, 0)},
 {'Age': 0, 'Agent Type': 'Predator', 'Food': 7, 'Location': (2, 0)}]

assert state["Sites"] == [{'Location': (0, 0),
  'Food': 2,
  'Agent': {'Age': 0, 'Agent Type': 'Prey', 'Food': 5, 'Location': (0, 0)}},
 {'Location': (0, 1),
  'Food': 1,
  'Agent': {'Age': 0, 'Agent Type': 'Prey', 'Food': 5, 'Location': (0, 1)}},
 {'Location': (1, 0),
  'Food': 0,
  'Agent': {'Age': 0, 'Agent Type': 'Prey', 'Food': 5, 'Location': (1, 0)}},
 {'Location': (1, 1),
  'Food': 2,
  'Agent': {'Age': 0,
   'Agent Type': 'Predator',
   'Food': 7,
   'Location': (1, 1)}},
 {'Location': (2, 0),
  'Food': 2,
  'Agent': {'Age': 0,
   'Agent Type': 'Predator',
   'Food': 7,
   'Location': (2, 0)}},
 {'Location': (2, 1), 'Food': 3, 'Agent': None}]

assert state["Stateful Metrics"]["Open Locations Stateful Metric"](state, params) == [{'Location': (2, 1), 'Food': 3, 'Agent': None}]
assert state["Stateful Metrics"]["Filled Locations Stateful Metric"](state, params) == [{'Location': (0, 0), 'Food': 2, 'Agent': {'Age': 0, 'Agent Type': 'Prey', 'Food': 5, 'Location': (0, 0)}}, {'Location': (0, 1), 'Food': 1, 'Agent': {'Age': 0, 'Agent Type': 'Prey', 'Food': 5, 'Location': (0, 1)}}, {'Location': (1, 0), 'Food': 0, 'Agent': {'Age': 0, 'Agent Type': 'Prey', 'Food': 5, 'Location': (1, 0)}}, {'Location': (1, 1), 'Food': 2, 'Agent': {'Age': 0, 'Agent Type': 'Predator', 'Food': 7, 'Location': (1, 1)}}, {'Location': (2, 0), 'Food': 2, 'Agent': {'Age': 0, 'Agent Type': 'Predator', 'Food': 7, 'Location': (2, 0)}}]
assert state["Stateful Metrics"]["Prey Locations Stateful Metric"](state, params) == [{'Location': (0, 0), 'Food': 2, 'Agent': {'Age': 0, 'Agent Type': 'Prey', 'Food': 5, 'Location': (0, 0)}}, {'Location': (0, 1), 'Food': 1, 'Agent': {'Age': 0, 'Agent Type': 'Prey', 'Food': 5, 'Location': (0, 1)}}, {'Location': (1, 0), 'Food': 0, 'Agent': {'Age': 0, 'Agent Type': 'Prey', 'Food': 5, 'Location': (1, 0)}}]
assert state["Stateful Metrics"]["Predator Locations Stateful Metric"](state, params) == [{'Location': (1, 1), 'Food': 2, 'Agent': {'Age': 0, 'Agent Type': 'Predator', 'Food': 7, 'Location': (1, 1)}}, {'Location': (2, 0), 'Food': 2, 'Agent': {'Age': 0, 'Agent Type': 'Predator', 'Food': 7, 'Location': (2, 0)}}]
assert state["Stateful Metrics"]["Median Site Food Stateful Metric"](state, params) == 2
assert state["Stateful Metrics"]["Prey Stateful Metric"](state, params) == [{'Age': 0, 'Agent Type': 'Prey', 'Food': 5, 'Location': (0, 0)}, {'Age': 0, 'Agent Type': 'Prey', 'Food': 5, 'Location': (0, 1)}, {'Age': 0, 'Agent Type': 'Prey', 'Food': 5, 'Location': (1, 0)}]
assert state["Stateful Metrics"]["Predator Stateful Metric"](state, params) == [{'Age': 0, 'Agent Type': 'Predator', 'Food': 7, 'Location': (1, 1)}, {'Age': 0, 'Agent Type': 'Predator', 'Food': 7, 'Location': (2, 0)}]
assert state["Stateful Metrics"]["Number of Prey Stateful Metric"](state, params) == 3
assert state["Stateful Metrics"]["Number of Predators Stateful Metric"](state, params) == 2
assert state["Stateful Metrics"]["Median Predator Food Stateful Metric"](state, params) == 7
assert state["Stateful Metrics"]["Median Prey Food Stateful Metric"](state, params) == 5
assert state["Stateful Metrics"]["Median Predator Age Stateful Metric"](state, params) == 0
assert state["Stateful Metrics"]["Median Prey Age Stateful Metric"](state, params) == 0
